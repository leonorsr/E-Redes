# %%
import geopandas as gpd

# Carregar o arquivo GeoJSON
mapa_portugal = gpd.read_file("pt.json")

# Exibir as primeiras linhas do GeoDataFrame para verificar se foi carregado corretamente
print(mapa_portugal.head())
# Out:
#                    source    id              name  \
# 0  https://simplemaps.com  PT07             Évora
# 1  https://simplemaps.com  PT12        Portalegre
# 2  https://simplemaps.com  PT16  Viana do Castelo
# 3  https://simplemaps.com  PT05    Castelo Branco
# 4  https://simplemaps.com  PT09            Guarda
#
#                                             geometry
# 0  POLYGON ((-7.22588 38.76613, -7.27043 38.73751...
# 1  POLYGON ((-7.22588 38.76613, -7.22625 38.76647...
# 2  POLYGON ((-8.17927 41.81261, -8.17978 41.81246...
# 3  POLYGON ((-7.55587 39.67721, -7.55615 39.67729...
# 4  POLYGON ((-6.9421 40.25498, -6.94249 40.25532,...

# %%
import matplotlib.pyplot as plt

# Visualizar o mapa de Portugal
mapa_portugal.plot(figsize=(10, 10))

# Ajuste do título
plt.title("Mapa de Portugal - Divisão Administrativa", fontsize=16)

# Exibir o mapa
plt.show()
